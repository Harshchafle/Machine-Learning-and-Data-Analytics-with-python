# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 65            66         1       3       Moubarek, Master. Gerios  male   NaN
# 588          589         0       3          Gilinski, Mr. Eliezer  male  22.0
# 248          249         1       1  Beckwith, Mr. Richard Leonard  male  37.0
# 105          106         0       3          Mionoff, Mr. Stoytcho  male  28.0
# 621          622         1       1   Kimball, Mr. Edwin Nelson Jr  male  42.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 65       1      1    2661  15.2458   NaN        C
# 588      0      0   14973   8.0500   NaN        S
# 248      1      1   11751  52.5542   D35        S
# 105      0      0  349207   7.8958   NaN        S
# 621      1      0   11753  52.5542   D19        S

# %% [markdown]
# # Univariate Analysis
# ## visualizing using seaborn

# %%
import seaborn as sns

# %% [markdown]
# ## Categorical Data

# %% [markdown]
# ## a. countplot

# %%
# using seaborn's countplot to show the count of unique values in column for particular variable
# sns.countplot(df['Survived'])
# sns.histplot(df['Survived'])

df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %% [markdown]
# ## PieChart

# %%
df['Survived'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
# to plot continuous data
import matplotlib.pyplot as plt
plt.hist(df['Age'], bins = 25)
# Out:
# (array([30., 17., 15.,  9., 29., 64., 67., 70., 83., 62., 51., 40., 35.,
#         27., 35., 23., 15.,  9., 11., 11.,  4.,  2.,  3.,  1.,  1.]),
#  array([ 0.42  ,  3.6032,  6.7864,  9.9696, 13.1528, 16.336 , 19.5192,
#         22.7024, 25.8856, 29.0688, 32.252 , 35.4352, 38.6184, 41.8016,
#         44.9848, 48.168 , 51.3512, 54.5344, 57.7176, 60.9008, 64.084 ,
#         67.2672, 70.4504, 73.6336, 76.8168, 80.    ]),
#  <BarContainer object of 25 artists>)

# %% [markdown]
# ## b. Distplot

# %%
# line -> kde (kernel density estimation)
sns.distplot(df['Age'])
# pdf -> probability density function
# distplot also shows skewness of data
# Out:
# /tmp/ipykernel_143/59740956.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## c. boxplot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: >

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704
