# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.isna().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# mapping input and output
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
# preparing training and testing data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=2)

# %%
# creating object of linear regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# training model
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([36833.63210301])

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('Experience in years')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
# metrics (sloper, intercept)
m = lr.coef_
b = lr.intercept_
print(f"Equation of best fit line : y = {m}x + {b:.2f}")
# Out:
# Equation of best fit line : y = [9569.58688543]x + 24393.17
