# %%
import numpy as np

# %%
a = np.array(4)

# %%
a, type(a)
# Out:
# (array(4), numpy.ndarray)

# %%
a.ndim
# Out:
# 0

# %%
arr = np.array([1,2,3,4])  # 1D tensor
arr
# Out:
# array([1, 2, 3, 4])

# %%
mat = np.array(     # 2D tensor
    [
        [1,2,3],
        [4,5,6],
    ]
)
mat
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
t3 = np.array([
    [
        [1,2],
        [3,4]
    ]
])
print(type(t3), t3.ndim)
# Out:
# <class 'numpy.ndarray'> 3
